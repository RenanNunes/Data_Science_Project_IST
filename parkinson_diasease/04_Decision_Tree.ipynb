# %% [markdown]
# # Lab 4 - Decision Tree
# The model that will be analyzed this time is Decision Trees.
#
# There are some parameters that influentiate the model, therefore the tests involve changing these parameters to see which returns the best result. The values will be:
#
# * The minimum number of samples required to be at a leaf node (in percentage): [.05, .025, .01, .0075, .005, .0025, .001]
# * The maximum depth of the tree: [5, 10, 25, 50]
# * The function to measure the quality of a split: ['entropy', 'gini']

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import RepeatedStratifiedKFold
import sklearn.metrics as metrics
import itertools
from utils import modelAnalyzesFunctions as analyzes

# %%
data_7: pd.DataFrame = pd.read_csv('../datasets/pd_data_preparation_7.csv', sep=',', decimal='.', index_col='id')
y_7: np.ndarray = data_7.pop('class').values
X_7: np.ndarray = data_7.values
labels_7 = pd.unique(y_7)

data_8: pd.DataFrame = pd.read_csv('../datasets/pd_data_preparation.csv', sep=',', decimal='.', index_col='id')
y_8: np.ndarray = data_8.pop('class').values
X_8: np.ndarray = data_8.values
labels_8 = pd.unique(y_8)

data_9: pd.DataFrame = pd.read_csv('../datasets/pd_data_preparation_9.csv', sep=',', decimal='.', index_col='id')
y_9: np.ndarray = data_9.pop('class').values
X_9: np.ndarray = data_9.values
labels_9 = pd.unique(y_9)

data_8.head()
# Out:
#     gender       PPE       DFA      RPDE  numPulses  stdDevPeriodPulses  \
# id
# 0      1.0  0.916232  0.475707  0.590235   0.284974            0.022323
# 1      0.0  0.182314  0.806469  0.630075   0.242228            0.689703
# 2      1.0  0.877689  0.216841  0.516437   0.448187            0.033848
# 3      0.0  0.925807  0.237611  0.542708   0.785622            0.010547
# 4      0.0  0.930451  0.757013  0.842307   0.532383            0.754983
#
#     locPctJitter  locShimmer  meanAutoCorrHarmonicity  minIntensity  ...  \
# id                                                                   ...
# 0       0.075900    0.271284                 0.944323      0.692855  ...
# 1       0.247423    0.228818                 0.876238      0.882924  ...
# 2       0.087255    0.117413                 0.974092      0.871010  ...
# 3       0.021814    0.161006                 0.983185      0.781731  ...
# 4       0.148962    0.722861                 0.734980      0.497109  ...
#
#     tqwt_kurtosisValue_dec_20  tqwt_kurtosisValue_dec_21  \
# id
# 0                    0.075621                   0.300582
# 1                    0.072430                   0.077755
# 2                    0.147429                   0.038159
# 3                    0.016141                   0.161223
# 4                    0.142211                   0.230036
#
#     tqwt_kurtosisValue_dec_22  tqwt_kurtosisValue_dec_23  \
# id
# 0                    0.105270                   0.013066
# 1                    0.174381                   0.038398
# 2                    0.013139                   0.007834
# 3                    0.097629                   0.037870
# 4                    0.117364                   0.022389
#
#     tqwt_kurtosisValue_dec_24  tqwt_kurtosisValue_dec_25  \
# id
# 0                    0.004055                   0.003293
# 1                    0.008310                   0.001114
# 2                    0.019385                   0.000201
# 3                    0.020783                   0.009404
# 4                    0.009184                   0.006695
#
#     tqwt_kurtosisValue_dec_26  tqwt_kurtosisValue_dec_27  \
# id
# 0                    0.000374                   0.000178
# 1                    0.001689                   0.024783
# 2                    0.000368                   0.000336
# 3                    0.018881                   0.003916
# 4                    0.009538                   0.010617
#
#     tqwt_kurtosisValue_dec_28  tqwt_kurtosisValue_dec_30
# id
# 0                    0.000191                   0.098628
# 1                    0.018258                   0.040204
# 2                    0.213153                   0.120303
# 3                    0.000815                   0.009216
# 4                    0.013877                   0.010267
#
# [5 rows x 255 columns]

# %%
n_splits = 4
n_repeats = 3

rskf = RepeatedStratifiedKFold(n_splits, n_repeats, random_state=42)

min_samples_leaf = [.05, .025, .01, .0075, .005, .0025, .001]
max_depths = [5, 10, 25, 50]
criteria = ['entropy', 'gini']

accuracy, sensitivity, decision_trees = analyzes.decision_tree_analyzes(X_8, y_8, min_samples_leaf, max_depths, criteria, rskf)

# %%
for c in criteria:
    max_acc, max_sens = analyzes.get_max_accuracy_sensitivity_data(accuracy, sensitivity, max_depths, min_samples_leaf, c)
    
    print()
    print(c, '- max accuracy:')
    print('Accuracy:', max_acc['acc'])
    print('Sensitivity:', max_acc['sens'])
    print('max_depth:', max_acc['max_depth'])
    print('min_samples_leaf:', max_acc['min_sample_leaf'])
    print()
    print(c, '- max sensitivity:')
    print('Accuracy:', max_sens['acc'])
    print('Sensitivity:', max_sens['sens'])
    print('max_depth:', max_sens['max_depth'])
    print('min_samples_leaf:', max_sens['min_sample_leaf'])
# Out:
# entropy - max accuracy:
# Accuracy: 0.7996453900709222
# Sensitivity: 0.7730496453900709
# max_depth: 50
# min_samples_leaf: 0.001
#
# entropy - max sensitivity:
# Accuracy: 0.7579787234042553
# Sensitivity: 0.7730496453900709
# max_depth: 5
# min_samples_leaf: 0.05
#
# gini - max accuracy:
# Accuracy: 0.8129432624113476
# Sensitivity: 0.7836879432624113
# max_depth: 50
# min_samples_leaf: 0.001
#
# gini - max sensitivity:
# Accuracy: 0.8102836879432624
# Sensitivity: 0.7872340425531914
# max_depth: 10
# min_samples_leaf: 0.001

# %% [markdown]
# Using the gini criteria happened to be best in this dataset. Comparing with other models, it's still worse than KNN's accuracy (one of them got 0.8528 accuracy), although the sensitivity is better ( > 0.7252).

# %% [markdown]
# ## Extra Datasets

# %%
accuracy_7, sensitivity_7, decision_trees_7 = analyzes.decision_tree_analyzes(X_7, y_7, min_samples_leaf, max_depths, criteria, rskf)

# %%
for c in criteria:
    max_acc, max_sens = analyzes.get_max_accuracy_sensitivity_data(accuracy_7, sensitivity_7, max_depths, min_samples_leaf, c)
    
    print()
    print(c, '- max accuracy:')
    print('Accuracy:', max_acc['acc'])
    print('Sensitivity:', max_acc['sens'])
    print('max_depth:', max_acc['max_depth'])
    print('min_samples_leaf:', max_acc['min_sample_leaf'])
    print()
    print(c, '- max sensitivity:')
    print('Accuracy:', max_sens['acc'])
    print('Sensitivity:', max_sens['sens'])
    print('max_depth:', max_sens['max_depth'])
    print('min_samples_leaf:', max_sens['min_sample_leaf'])
# Out:
# entropy - max accuracy:
# Accuracy: 0.7952127659574467
# Sensitivity: 0.7712765957446809
# max_depth: 25
# min_samples_leaf: 0.0075
#
# entropy - max sensitivity:
# Accuracy: 0.7952127659574467
# Sensitivity: 0.7712765957446809
# max_depth: 25
# min_samples_leaf: 0.0075
#
# gini - max accuracy:
# Accuracy: 0.8120567375886524
# Sensitivity: 0.776595744680851
# max_depth: 10
# min_samples_leaf: 0.001
#
# gini - max sensitivity:
# Accuracy: 0.7757092198581561
# Sensitivity: 0.7978723404255321
# max_depth: 5
# min_samples_leaf: 0.025

# %%
accuracy_9, sensitivity_9, decision_trees_9 = analyzes.decision_tree_analyzes(X_9, y_9, min_samples_leaf, max_depths, criteria, rskf)

# %%
for c in criteria:
    max_acc, max_sens = analyzes.get_max_accuracy_sensitivity_data(accuracy_9, sensitivity_9, max_depths, min_samples_leaf, c)
    
    print()
    print(c, '- max accuracy:')
    print('Accuracy:', max_acc['acc'])
    print('Sensitivity:', max_acc['sens'])
    print('max_depth:', max_acc['max_depth'])
    print('min_samples_leaf:', max_acc['min_sample_leaf'])
    print()
    print(c, '- max sensitivity:')
    print('Accuracy:', max_sens['acc'])
    print('Sensitivity:', max_sens['sens'])
    print('max_depth:', max_sens['max_depth'])
    print('min_samples_leaf:', max_sens['min_sample_leaf'])
# Out:
# entropy - max accuracy:
# Accuracy: 0.8404255319148936
# Sensitivity: 0.8049645390070922
# max_depth: 50
# min_samples_leaf: 0.005
#
# entropy - max sensitivity:
# Accuracy: 0.8244680851063831
# Sensitivity: 0.828014184397163
# max_depth: 25
# min_samples_leaf: 0.0075
#
# gini - max accuracy:
# Accuracy: 0.8058510638297873
# Sensitivity: 0.7570921985815602
# max_depth: 50
# min_samples_leaf: 0.001
#
# gini - max sensitivity:
# Accuracy: 0.7934397163120567
# Sensitivity: 0.7588652482269503
# max_depth: 10
# min_samples_leaf: 0.01

# %% [markdown]
# Here we can see that the entropy criteria ended up with a better accuracy and senstivity than the 0.8's dataset, showing how well decision trees can handle high dimensionality.
#
# To ilustrate the decision tree, one example will be plotted below.

# %%
from sklearn.tree import export_graphviz

dot_data = export_graphviz(decision_trees_9['entropy'][25][10], out_file='dtree.dot', filled=True, rounded=True, special_characters=True)  
# Convert to png
from subprocess import call
call(['dot', '-Tpng', 'dtree.dot', '-o', 'dtree.png', '-Gdpi=600'])

plt.figure(figsize = (30, 40))
plt.imshow(plt.imread('dtree.png'))
plt.axis('off')
plt.show()

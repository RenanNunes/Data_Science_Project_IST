# %% [markdown]
# O lab 0 foi mais para revisar python e matplotlib, então só fiz alguns comandos aqui

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters

register_matplotlib_converters()

# %%
algae = pd.read_csv('datasets/algae.csv', index_col='date', sep=',', decimal='.', parse_dates=True, infer_datetime_format=True)
algae
# Out:
#               pH  Oxygen  Chloride  Nitrates  Ammonium  Orthophosphate  \
# date
# 2018-09-30  8.10   11.40     40.02      5.33    346.67          125.67
# 2018-10-05  8.06    9.00     55.35     10.42    233.70           58.22
# 2018-10-07  8.05   10.60     59.07      4.99    205.67           44.67
# 2018-10-09  7.55   11.50      4.70      1.32     14.75            4.25
# 2018-10-11  7.75   10.30     32.92      2.94     42.00           16.00
# 2018-10-13  6.80   11.10      9.00      0.63     20.00            4.00
# 2018-10-15  7.40   12.50     13.00      3.33     60.00           72.00
# 2018-10-17  8.40    9.90     34.50      2.82     20.00           47.00
# 2018-10-19  8.00   12.10     66.30      4.54     39.00           16.00
# 2018-10-21  7.29   11.21     17.75      3.07     35.00           13.00
# 2018-10-23  5.70   10.80       NaN      2.55     10.00            1.00
# 2018-10-25  6.60   11.30       NaN      4.17     10.00            1.00
# 2018-10-27  7.83   11.70      4.08      1.33     18.00            3.33
# 2018-10-29  8.50    8.10     38.13      3.85    225.00           45.00
# 2018-10-31  8.10    9.80     29.50      1.29    224.29           25.17
# 2018-11-02  7.30   11.70     10.40      4.93    130.00           10.80
# 2018-11-04  7.50   10.80     31.00      4.41    737.50          111.25
# 2018-11-06  8.50   10.50     56.72      0.33    215.71           23.00
# 2018-11-08  7.60   10.00     49.63      5.46    308.75           38.63
# 2018-11-10  8.30   11.10     41.50      4.67    931.83           39.00
# 2018-11-12  8.30   11.60      5.83      0.70     12.73            3.55
# 2018-11-14  8.00   11.90    130.67      6.54    196.00           75.00
# 2018-11-16  8.10   11.70     35.66      5.13     46.50           49.00
# 2018-11-18  7.90   10.50     10.21      2.30    132.25           10.58
# 2018-11-20  7.80    6.50     64.09      7.74     47.50          276.00
# 2018-11-22  8.30    9.90     40.23      1.59    235.00           33.80
# 2018-11-24  8.87   11.00     41.16      2.27     54.75           39.00
# 2018-11-26  7.30   11.80     44.21     45.65     44.00           34.00
# 2018-11-28  7.80   10.53    100.83      5.41    486.50           24.00
# 2018-11-30  8.40   10.60     19.22      1.66     96.83           20.67
# ...          ...     ...       ...       ...       ...             ...
# 2019-07-21  7.40   11.17     12.15      6.19     89.60           32.00
# 2019-07-23  7.40   10.77     36.25      3.73    429.20           57.60
# 2019-07-25  7.60    9.70     53.10      7.16    282.17          624.73
# 2019-07-27  8.10   10.70     94.41      4.70    153.00          191.75
# 2019-07-29  7.90   11.80     63.51      4.94    137.00          159.50
# 2019-07-31  7.80    8.20     85.98      6.20    421.67           31.33
# 2019-08-02  7.50    8.80     58.33      8.69    758.75          104.50
# 2019-08-04  7.70   11.10     47.23      8.76    239.00           54.00
# 2019-08-06  8.16   11.10     32.06      5.69    461.88           71.00
# 2019-08-08  8.50   11.80      7.84      1.73    206.54            8.69
# 2019-08-10  8.00    9.70     57.85      0.46    217.75           37.00
# 2019-08-12  8.60   11.62      1.55      0.45     25.83           16.83
# 2019-08-14  8.20    6.60    131.40      4.19     92.00          238.20
# 2019-08-16  8.10    9.00     48.43      6.64    128.57          181.00
# 2019-08-18  8.60   10.70     12.00      2.23     43.75           62.63
# 2019-08-20  8.30   10.00     30.13      3.73    102.50           75.88
# 2019-08-22  7.30   10.50     11.09      1.37     92.38           48.63
# 2019-08-24  8.10    6.20     39.00      0.67    112.86           60.00
# 2019-08-26  8.10    6.20     51.11      5.10    175.00          132.50
# 2019-08-28  7.70    4.40     53.00      2.31     90.00           22.20
# 2019-08-30  7.60    4.90     69.00      3.68    234.50          236.00
# 2019-09-01  8.80    8.80     43.00      0.13    103.33          180.67
# 2019-09-03  7.91    6.20    151.83      3.92    346.17          388.17
# 2019-09-05  8.40   10.29      5.33      1.00     53.85            7.67
# 2019-09-07  8.20    9.50      2.20      0.67     10.00            3.80
# 2019-09-09  8.30   10.00      3.86      0.87     32.00            6.00
# 2019-09-11  8.10   10.20      7.61      0.70     32.50           26.63
# 2019-09-13  8.40    8.20     23.25      2.81     43.75           51.13
# 2019-09-15  8.50    7.90     12.44      2.59     96.67           19.11
# 2019-09-17  8.50    6.70     82.85      2.80     27.07           64.00
#
#             Phosphate  Chlorophyll fluid_velocity river_depth  season
# date
# 2018-09-30     187.06        15.60         medium         low  autumn
# 2018-10-05      97.58        10.50         medium         low  autumn
# 2018-10-07      77.43         6.90           high         low  autumn
# 2018-10-09      98.25         1.10           high         low  autumn
# 2018-10-11      40.00         7.60           high         low  autumn
# 2018-10-13        NaN         2.70           high         low  autumn
# 2018-10-15     142.00         4.90           high         low  autumn
# 2018-10-17       2.30        13.60         medium         low  autumn
# 2018-10-19      39.00         0.80           high         low  autumn
# 2018-10-21      20.81        12.10         medium         low  autumn
# 2018-10-23       4.00          NaN         medium         low  autumn
# 2018-10-25       6.00          NaN         medium         low  autumn
# 2018-10-27       6.67          NaN           high         low  autumn
# 2018-10-29     152.33         5.20         medium      medium  autumn
# 2018-10-31     102.33         3.60         medium      medium  autumn
# 2018-11-02      60.00         4.30           high      medium  autumn
# 2018-11-04     214.00         2.90         medium      medium  autumn
# 2018-11-06     138.50        20.83            low      medium  autumn
# 2018-11-08     285.71        75.00            low      medium  autumn
# 2018-11-10     124.20        13.10           high      medium  autumn
# 2018-11-12      13.20         3.20         medium      medium  autumn
# 2018-11-14      84.00         4.50         medium      medium  autumn
# 2018-11-16      88.50         2.50         medium      medium  autumn
# 2018-11-18      23.49         2.00           high      medium  autumn
# 2018-11-20       8.10         6.50            low      medium  autumn
# 2018-11-22      75.21        23.80           high      medium  autumn
# 2018-11-24      72.70        22.70           high      medium  autumn
# 2018-11-26      53.10         2.20           high      medium  autumn
# 2018-11-28      58.37        27.50         medium      medium  autumn
# 2018-11-30      54.92        20.60            low        high  autumn
# ...               ...          ...            ...         ...     ...
# 2019-07-21      69.93         3.10           high      medium  summer
# 2019-07-23     169.00         3.20         medium      medium  summer
# 2019-07-25       6.80         0.00         medium      medium  summer
# 2019-07-27     265.25         7.30         medium      medium  summer
# 2019-07-29     218.00         6.50           high      medium  summer
# 2019-07-31     211.67        21.90           high      medium  summer
# 2019-08-02     292.63         3.00            low      medium  summer
# 2019-08-04     275.14        65.70            low      medium  summer
# 2019-08-06     132.55        15.00           high      medium  summer
# 2019-08-08      16.66         2.10           high      medium  summer
# 2019-08-10      87.00         3.00         medium      medium  summer
# 2019-08-12      18.29         1.40           high      medium  summer
# 2019-08-14     320.40         6.80            low      medium  summer
# 2019-08-16     222.29         6.43         medium      medium  summer
# 2019-08-18      89.63         2.15           high      medium  summer
# 2019-08-20     177.63        50.23         medium      medium  summer
# 2019-08-22      66.75         3.30           high      medium  summer
# 2019-08-24      98.14         2.00            low      medium  summer
# 2019-08-26     197.14         6.40         medium      medium  summer
# 2019-08-28     116.20        16.00           high      medium  summer
# 2019-08-30      22.50        32.50            low        high  summer
# 2019-09-01     269.67        92.67            low        high  summer
# 2019-09-03       5.08         1.70         medium        high  summer
# 2019-09-05      14.35         0.80           high        high  summer
# 2019-09-07       6.20         0.80         medium        high  summer
# 2019-09-09      16.00         2.86         medium        high  summer
# 2019-09-11      52.88         2.00           high        high  summer
# 2019-09-13      87.13        14.78            low        high  summer
# 2019-09-15      61.44         6.17         medium        high  summer
# 2019-09-17     140.52        18.30         medium        high  summer
#
# [200 rows x 11 columns]

# %%
ph = algae['pH']
ph
# Out:
# date
# 2018-09-30    8.10
# 2018-10-05    8.06
# 2018-10-07    8.05
# 2018-10-09    7.55
# 2018-10-11    7.75
# 2018-10-13    6.80
# 2018-10-15    7.40
# 2018-10-17    8.40
# 2018-10-19    8.00
# 2018-10-21    7.29
# 2018-10-23    5.70
# 2018-10-25    6.60
# 2018-10-27    7.83
# 2018-10-29    8.50
# 2018-10-31    8.10
# 2018-11-02    7.30
# 2018-11-04    7.50
# 2018-11-06    8.50
# 2018-11-08    7.60
# 2018-11-10    8.30
# 2018-11-12    8.30
# 2018-11-14    8.00
# 2018-11-16    8.10
# 2018-11-18    7.90
# 2018-11-20    7.80
# 2018-11-22    8.30
# 2018-11-24    8.87
# 2018-11-26    7.30
# 2018-11-28    7.80
# 2018-11-30    8.40
#               ...
# 2019-07-21    7.40
# 2019-07-23    7.40
# 2019-07-25    7.60
# 2019-07-27    8.10
# 2019-07-29    7.90
# 2019-07-31    7.80
# 2019-08-02    7.50
# 2019-08-04    7.70
# 2019-08-06    8.16
# 2019-08-08    8.50
# 2019-08-10    8.00
# 2019-08-12    8.60
# 2019-08-14    8.20
# 2019-08-16    8.10
# 2019-08-18    8.60
# 2019-08-20    8.30
# 2019-08-22    7.30
# 2019-08-24    8.10
# 2019-08-26    8.10
# 2019-08-28    7.70
# 2019-08-30    7.60
# 2019-09-01    8.80
# 2019-09-03    7.91
# 2019-09-05    8.40
# 2019-09-07    8.20
# 2019-09-09    8.30
# 2019-09-11    8.10
# 2019-09-13    8.40
# 2019-09-15    8.50
# 2019-09-17    8.50
# Name: pH, Length: 200, dtype: float64

# %%
len(ph)
# Out:
# 200

# %%
print(ph[-1])
print(ph['2019-09-17'])
print(ph[:4])
print(ph[:'2018-10-09'])
# Out:
# 8.5
# 8.5
# date
# 2018-09-30    8.10
# 2018-10-05    8.06
# 2018-10-07    8.05
# 2018-10-09    7.55
# Name: pH, dtype: float64
# date
# 2018-09-30    8.10
# 2018-10-05    8.06
# 2018-10-07    8.05
# 2018-10-09    7.55
# Name: pH, dtype: float64

# %%
algae.head()
# Out:
#               pH  Oxygen  Chloride  Nitrates  Ammonium  Orthophosphate  \
# date
# 2018-09-30  8.10    11.4     40.02      5.33    346.67          125.67
# 2018-10-05  8.06     9.0     55.35     10.42    233.70           58.22
# 2018-10-07  8.05    10.6     59.07      4.99    205.67           44.67
# 2018-10-09  7.55    11.5      4.70      1.32     14.75            4.25
# 2018-10-11  7.75    10.3     32.92      2.94     42.00           16.00
#
#             Phosphate  Chlorophyll fluid_velocity river_depth  season
# date
# 2018-09-30     187.06         15.6         medium         low  autumn
# 2018-10-05      97.58         10.5         medium         low  autumn
# 2018-10-07      77.43          6.9           high         low  autumn
# 2018-10-09      98.25          1.1           high         low  autumn
# 2018-10-11      40.00          7.6           high         low  autumn

# %%
plt.figure(num=1, figsize=(5,4))

# %%
plt.plot(algae['pH'])
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.ylim(0,14)
plt.title('pH along time')
plt.xlabel('date')
plt.ylabel('pH')
plt.plot(algae['pH'])
plt.show()

# %%
def choose_grid(nr):
    return nr // 4 + 1, 4
print('Teste')
print(choose_grid(0))
print(choose_grid(1))
print(choose_grid(2))
print(choose_grid(3))
print(choose_grid(4))
print(choose_grid(5))
# Out:
# Teste
# (1, 4)
# (1, 4)
# (1, 4)
# (1, 4)
# (2, 4)
# (2, 4)

# %%
def line_chart(ax: plt.Axes, series: pd.Series, title: str, xlabel: str, ylabel: str, percentage=False):
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    if percentage:
        ax.set_ylim(0.0, 1.0)
    ax.plot(series)

(rows, cols) = choose_grid(algae.shape[1])
plt.figure()
fig, axs = plt.subplots(rows, cols, figsize=(cols*5, rows*5))
i, j, n = 0, 0, 0

for col in algae:
    line_chart(axs[i, j], algae[col], col, 'date,', col)
    n = n + 1
    i, j = (i + 1, 0) if n% cols == 0 else (i, j + 1)
fig.tight_layout()
plt.show()

# %%
def multiple_line_chart(ax: plt.Axes, xvalues: list, yvalues: dict, title: str, xlabel:str, ylabel: str, percentage=False):
    legend: list = []
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    if percentage:
        ax.set_ylim(0.0, 1.0)
        
    for name, y in yvalues.items():
        ax.plot(xvalues, y)
        legend.append(name)
    ax.legend(legend, loc='best', fancybox = True, shadow = True)

plt.figure(figsize=(12,4))
two_series = {'Phosphate': algae['Phosphate'], 'Orthophosphate': algae['Orthophosphate']}
multiple_line_chart(plt.gca(), algae.index, two_series, 'Phosphate and Orthophosphate values', 'date', '')
plt.show()

# %%
def bar_chart(ax: plt.Axes, xvalues: list, yvalues: list, title: str, xlabel: str, ylabel: str, percentage=False):
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_xticklabels(xvalues, rotation=90, fontsize='small')
    if percentage:
        ax.set_ylim(0.0, 1.0)
    ax.bar(xvalues, yvalues, edgecolor='grey')
    
plt.figure()
counts = algae['season'].value_counts()
bar_chart(plt.gca(), counts.index, counts.values, 'season distribution', 'season', 'frequency')
plt.show()

# %%
import numpy as np

def multiple_bar_chart(ax: plt.Axes, xvalues: list, yvalues: dict, title: str, xlabel: str, ylabel: str, percentage=False):
    
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    x = np.arange(len(xvalues)) # the label locations
    ax.set_xticks(x)
    ax.set_xticklabels(xvalues, fontsize='small')
    if percentage:
        ax.set_ylim(0.0, 1.0)
    width = 0.8 # the width of the bars
    step = width / len(yvalues)
    k = 0
    for name, y in yvalues.items():
        ax.bar(x + k * step, y, step, label=name)
        k += 1
    ax.legend(loc='lower center', ncol=len(yvalues), bbox_to_anchor=(0.5, -0.2), fancybox = True, shadow = True)
    
two_series = {'river_depth': algae['river_depth'].value_counts().sort_index(), 'fluid_velocity': algae['fluid_velocity'].value_counts().sort_index()}
plt.figure()
multiple_bar_chart(plt.gca(), ['high', 'low', 'medium'], two_series, '', '', 'frequency')
plt.show()
# Out:
# yvalues {'river_depth': high      45
# low       71
# medium    84
# Name: river_depth, dtype: int64, 'fluid_velocity': high      84
# low       33
# medium    83
# Name: fluid_velocity, dtype: int64} len(yvalues) 2 step 0.4
